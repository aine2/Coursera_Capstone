# %% [markdown]
# # Capstone - Final Assignment - Presentation

# %% [markdown]
# ###### By Aine Webster

# %% [markdown]
# ________________________________________

# %% [markdown]
# # Proposal of a Business Expansion Strategy using Location Data

# %% [markdown]
# ________________________________________

# %% [markdown]
# #### You are a new jewellery store located in London ready to expand!
# #### But... how do you know what the best new location may be?

# %% [markdown]
# # One way is to use location data to visualize and analyse your current competition and your potential demand!

# %% [markdown]
# ________________________________________

# %% [markdown]
# ### I. Use location data to map your competition:

# %%
venues_map = folium.Map(location=[latitude, longitude], zoom_start=13) # generate map centred around the Conrad Hotel

# add the Italian restaurants as blue circle markers
for lat, lng, label in zip(birmingham_final.lat, birmingham_final.lng, birmingham_final.categories):
    folium.features.CircleMarker(
        [lat, lng],
        radius=5,
        color='blue',
        popup=label,
        fill = True,
        fill_color='blue',
        fill_opacity=0.6
    ).add_to(venues_map)

# display map
venues_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# #### Summary: In a location like Birmingham, jewellery stores are mainly located around the "jewellery quarter" - this may be a hard market to break because customers know and recognise this area and introducing a new brand here means
#
#          1) Not necessarily gaining customers because your brand is not well known
#
#          2) High competition

# %% [markdown]
# ### II. Use location data to understand a potential gap in the market:

# %%
bar_graph_result.plot(kind='bar')
plt.title('Total Jewelry Stores to Retail Stores Ratio')
plt.xlabel('City')
plt.ylabel('Ratio')
plt.xticks(np.arange(4), ('Birmingham', 'Glasgow', 'Liverpool', 'Bristol'))

plt.show()

# %% [markdown]
# #### Summary: A ratio can be created to look at the number of jewellery stores to total retail stores. This can show you where there is low jewellery stores relative to total shops in the area, and therefore an opportunity for a need for jewellery stores. Bristol has a much lower ratio - there is more need for jewellery stores and potential demand is likely to be higher!
